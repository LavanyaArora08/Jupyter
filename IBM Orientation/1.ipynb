# %%
import pandas as pd
import numpy as np

# %%
pd.Timestamp('17th August 2023 10:10')
#determineIndex -> df and series index
pd.DatetimeIndex([pd.Timestamp('17th August 2023 10:10'), pd.Timestamp('18th August 2023 10:10'), pd.Timestamp('19th August 2023 10:10')])
#dateRange 
pd.date_range(start='2023-08-17', end='2023-08-31', freq='D')
#to_datetime
s=pd.Series(['2023-08-17', '2023-08-18', '2023-08-19'])
pd.to_datetime(s)
#pd.to_datetime(s),dt.month_name()
# Out:
# 0   2023-08-17
# 1   2023-08-18
# 2   2023-08-19
# dtype: datetime64[ns]

# %%
#create using Timestamp fucntion
t1=pd.Timestamp('6th Jan 2023 8:23:34')
t2=pd.Timestamp('27th Jan 2023 10:00:00')

t2-t1
# Out:
# Timedelta('21 days 01:36:26')

# %%
#standalone creation
pd.Timedelta(days=10, hours= 10, minutes=35)
# Out:
# Timedelta('10 days 10:35:00')

# %%
#arithmetic
pd.Timestamp('6th Jan 2023') + pd.Timedelta(days=5, hours=10, minutes=25)
# Out:
# Timestamp('2023-01-11 10:25:00')

# %%
pd.date_range(start='2023-1-6', end='2023-1-31', freq='D')+pd.Timedelta(days=2, hours=12, minutes=35)
# Out:
# DatetimeIndex(['2023-01-08 12:35:00', '2023-01-09 12:35:00',
#                '2023-01-10 12:35:00', '2023-01-11 12:35:00',
#                '2023-01-12 12:35:00', '2023-01-13 12:35:00',
#                '2023-01-14 12:35:00', '2023-01-15 12:35:00',
#                '2023-01-16 12:35:00', '2023-01-17 12:35:00',
#                '2023-01-18 12:35:00', '2023-01-19 12:35:00',
#                '2023-01-20 12:35:00', '2023-01-21 12:35:00',
#                '2023-01-22 12:35:00', '2023-01-23 12:35:00',
#                '2023-01-24 12:35:00', '2023-01-25 12:35:00',
#                '2023-01-26 12:35:00', '2023-01-27 12:35:00',
#                '2023-01-28 12:35:00', '2023-01-29 12:35:00',
#                '2023-01-30 12:35:00', '2023-01-31 12:35:00',
#                '2023-02-01 12:35:00', '2023-02-02 12:35:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
#real life example
df = pd.read_csv('C:\\Users\\arora\\Desktop\\IBM datasets\\deliveries.csv')
df.head()
# Out:
#   order_date delivery_date
# 0    5/24/98        2/5/99
# 1    4/22/92        3/6/98
# 2    2/10/91       8/26/92
# 3    7/21/92      11/20/97
# 4     9/2/93       6/10/98

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_date     501 non-null    object
#  1   delivery_date  501 non-null    object
# dtypes: object(2)
# memory usage: 8.0+ KB

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df['order_date'] 
df['delivery_date'] = pd.to_datetime(df['delivery_date'])
df['delivery_date']
# Out:
# 0     1999-02-05
# 1     1998-03-06
# 2     1992-08-26
# 3     1997-11-20
# 4     1998-06-10
#          ...
# 496   1996-02-02
# 497   1998-03-30
# 498   1998-04-27
# 499   1993-06-13
# 500   1991-10-03
# Name: delivery_date, Length: 501, dtype: datetime64[ns]

# %%
df['delivery_time_period']= df['delivery_date']-df['order_date']
df['delivery_time_period'].head()

df['delivery_time_period'].mean()
# Out:
# Timedelta('1217 days 22:53:53.532934128')

# %%
google = pd.read_csv('C:\\Users\\arora\\Desktop\\IBM datasets\\google.csv')
google.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 1  2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2  2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 3  2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 4  2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
google.tail()
# Out:
#             Date         Open         High          Low        Close  \
# 4466  2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098
# 4467  2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029
# 4468  2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020
# 4469  2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912
# 4470  2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010
#
#         Adj Close   Volume
# 4466  2295.850098  1164100
# 4467  2334.030029  1078800
# 4468  2248.020020  1399100
# 4469  2214.909912  1459600
# 4470  2186.260010  1878100

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   object
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 244.6+ KB

# %%
google['Date']=pd.to_datetime(google['Date'])
google['Date']
# Out:
# 0      2004-08-19
# 1      2004-08-20
# 2      2004-08-23
# 3      2004-08-24
# 4      2004-08-25
#           ...
# 4466   2022-05-16
# 4467   2022-05-17
# 4468   2022-05-18
# 4469   2022-05-19
# 4470   2022-05-20
# Name: Date, Length: 4471, dtype: datetime64[ns]

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4471 entries, 0 to 4470
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       4471 non-null   datetime64[ns]
#  1   Open       4471 non-null   float64
#  2   High       4471 non-null   float64
#  3   Low        4471 non-null   float64
#  4   Close      4471 non-null   float64
#  5   Adj Close  4471 non-null   float64
#  6   Volume     4471 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 244.6 KB

# %%
google.set_index('Date', inplace=True)

# %%
google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276

# %%
#fetch a specific date
google.loc['2021-12-28']
# Out:
# Open           2967.489990
# High           2967.489990
# Low            2918.709961
# Close          2928.959961
# Adj Close      2928.959961
# Volume       931200.000000
# Name: 2021-12-28 00:00:00, dtype: float64

# %%
#partial indexing--select a particular year/month
google.loc['2021-12']
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-12-01  2884.250000  2929.982910  2830.000000  2832.360107  2832.360107
# 2021-12-02  2836.479980  2893.500000  2819.639893  2875.530029  2875.530029
# 2021-12-03  2889.909912  2904.260010  2823.000000  2850.409912  2850.409912
# 2021-12-06  2871.479980  2887.030029  2812.939941  2875.929932  2875.929932
# 2021-12-07  2919.000000  2966.000000  2914.050049  2960.729980  2960.729980
# 2021-12-08  2966.629883  2983.129883  2944.000000  2974.409912  2974.409912
# 2021-12-09  2963.520020  2992.100098  2950.580078  2962.120117  2962.120117
# 2021-12-10  2982.000000  2988.000000  2947.149902  2973.500000  2973.500000
# 2021-12-13  2968.879883  2971.250000  2927.199951  2934.090088  2934.090088
# 2021-12-14  2895.399902  2908.840088  2844.850098  2899.409912  2899.409912
# 2021-12-15  2887.320068  2950.344971  2854.110107  2947.370117  2947.370117
# ...

# %%
google['month_name']=google.index.month_name()
google['weekday_name']=google.index.day_name() 
google['quater']=google.index.quarter

google.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2004-08-19  49.813290  51.835709  47.800831  49.982655  49.982655  44871361
# 2004-08-20  50.316402  54.336334  50.062355  53.952770  53.952770  22942874
# 2004-08-23  55.168217  56.528118  54.321388  54.495735  54.495735  18342897
# 2004-08-24  55.412300  55.591629  51.591621  52.239197  52.239197  15319808
# 2004-08-25  52.284027  53.798351  51.746044  52.802086  52.802086   9232276
#
#            month_name weekday_name  quater
# Date
# 2004-08-19     August     Thursday       3
# 2004-08-20     August       Friday       3
# 2004-08-23     August       Monday       3
# 2004-08-24     August      Tuesday       3
# 2004-08-25     August    Wednesday       3

# %%
pd.date_range(start='2005-1-6', end='2022-1-6', freq='D')
# Out:
# DatetimeIndex(['2005-01-06', '2005-01-07', '2005-01-08', '2005-01-09',
#                '2005-01-10', '2005-01-11', '2005-01-12', '2005-01-13',
#                '2005-01-14', '2005-01-15',
#                ...
#                '2021-12-28', '2021-12-29', '2021-12-30', '2021-12-31',
#                '2022-01-01', '2022-01-02', '2022-01-03', '2022-01-04',
#                '2022-01-05', '2022-01-06'],
#               dtype='datetime64[ns]', length=6210, freq='D')

# %%
pd.date_range(start='2005-1-6', end='2022-01-6', freq=pd.Timedelta(years=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 pd.date_range(start='2005-1-6', end='2022-01-6', freq=pd.Timedelta(years=1))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\tslibs\timedeltas.pyx:1711, in pandas._libs.tslibs.timedeltas.Timedelta.__new__()
#
# ValueError: cannot construct a Timedelta from the passed arguments, allowed keywords are [weeks, days, hours, minutes, seconds, milliseconds, microseconds, nanoseconds]

# %%
pd.date_range(start='2005-1-6', end='2022-01-6', freq=pd.Timedelta(days=365))
# Out:
# DatetimeIndex(['2005-01-06', '2006-01-06', '2007-01-06', '2008-01-06',
#                '2009-01-05', '2010-01-05', '2011-01-05', '2012-01-05',
#                '2013-01-04', '2014-01-04', '2015-01-04', '2016-01-04',
#                '2017-01-03', '2018-01-03', '2019-01-03', '2020-01-03',
#                '2021-01-02', '2022-01-02'],
#               dtype='datetime64[ns]', freq='365D')

# %%
#challenge -> fetch info from a particular date every year -> limitation of timedelta
google.head()

google[google.index.isin(pd.date_range(start='2005-01-06', end='2022-01-6', freq=pd.DateOffset(years=1)))]
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2005-01-06    97.175758    97.584229    93.509506    93.922951    93.922951
# 2006-01-06   227.581970   234.371521   225.773743   231.960556   231.960556
# 2009-01-06   165.868286   169.763687   162.585587   166.406265   166.406265
# 2010-01-06   311.761444   311.761444   302.047852   302.994293   302.994293
# 2011-01-06   304.199799   308.060303   303.885956   305.604523   305.604523
# 2012-01-06   328.344299   328.767700   323.681763   323.796326   323.796326
# 2014-01-06   554.426880   557.340942   551.154114   556.573853   556.573853
# 2015-01-06   513.589966   514.761719   499.678131   500.585632   500.585632
# 2016-01-06   730.000000   747.179993   728.919983   743.619995   743.619995
# 2017-01-06   795.260010   807.900024   792.203979   806.150024   806.150024
# 2020-01-06  1350.000000  1396.500000  1350.000000  1394.209961  1394.209961
# ...

# %%
google['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
subset_google = google[['Open','High','Low','Close','Volume']]
ax = subset_google.plot(subplots=True, layout=(3,2),sharex=False,sharey=False,linewidth=0.7,fontsize=10,legend=False,figsize=(20,15),Title=['Open','High','Low','Close','Volume'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 2
#       1 subset_google = google[['Open','High','Low','Close','Volume']]
# ----> 2 ax = subset_google.plot(subplots=True, layout=(3,2),sharex=False,sharey=False,linewidth=0.7,fontsize=10,legend=False,figsize=(20,15),Title=['Open','High','Low','Close','Volume'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
#plot for particular year/month/day
google.loc['2021']['Close'].plot()
google.loc['2021-12']['Close'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#asfreq
google.asfreq('D')
google.asfreq('B')
#google.asfreq('Q')
#google.asfreq('Y')
#google.asfreq('6H')
#google.asfreq('6H',method='bfill')
#google.asfreq('6H',method='ffill')
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2004-08-19    49.813290    51.835709    47.800831    49.982655    49.982655
# 2004-08-20    50.316402    54.336334    50.062355    53.952770    53.952770
# 2004-08-23    55.168217    56.528118    54.321388    54.495735    54.495735
# 2004-08-24    55.412300    55.591629    51.591621    52.239197    52.239197
# 2004-08-25    52.284027    53.798351    51.746044    52.802086    52.802086
# ...                 ...          ...          ...          ...          ...
# 2022-05-16  2307.679932  2332.149902  2286.699951  2295.850098  2295.850098
# 2022-05-17  2344.550049  2344.550049  2306.750000  2334.030029  2334.030029
# 2022-05-18  2304.750000  2313.913086  2242.840088  2248.020020  2248.020020
# 2022-05-19  2236.820068  2271.750000  2209.360107  2214.909912  2214.909912
# 2022-05-20  2241.709961  2251.000000  2127.459961  2186.260010  2186.260010
#
# ...
